# %%
"""
This script extracts camera extrinsics and intrinsics using COLMAP.

The directory structure of the root directory should be as follows:
root_dir
|   calib
|   |   *cam*
|   |   |   image_*.jpg

Run the script using:
    python colmap_params.py -r <root_dir>

The parameters will be stored in <root_dir>/calib/params.txt.
"""

import os
import logging
import subprocess
import sqlite3
import numpy as np
import cv2
import shutil
from numpy.lib import recfunctions as rf
from tqdm import tqdm
from cv2 import aruco
from glob import glob
from argparse import ArgumentParser
import moviepy.editor

logging.getLogger().setLevel(logging.INFO)

MARKER_AREA_THRESHOLD = 1000 # Parameter
MAX_IMAGE_ID = 2**31 - 1

debug = False

tmp_dir = os.path.join("tmp", "brics_calib")

def create_dir(path: str):
    """ Creates a directory also deleting previous one if it exissts """
    logging.warning(f"Deleting files at {path}")
    try:
        shutil.rmtree(path)
    except:
        pass
    os.makedirs(path)

def image_ids_to_pair_id(image_id1, image_id2):
    if image_id1 > image_id2:
        image_id1, image_id2 = image_id2, image_id1
    return image_id1 * MAX_IMAGE_ID + image_id2

def array_to_blob(array):
    return array.tobytes()

def blob_to_array(blob, dtype, shape=(-1,)):
    return np.frombuffer(blob, dtype=dtype).reshape(*shape)

def get_images(args, db_path, image_dir):
    connection = sqlite3.connect(db_path)
    cursor = connection.cursor()
    cursor.execute("SELECT image_id, name FROM images;")
    image_ids, image_paths = zip(*cursor.fetchall())
    image_ids = list(image_ids)
    image_paths = [os.path.join(image_dir, image_path) for image_path in image_paths]
    cursor.close()
    connection.close()
    return image_ids, image_paths

def add_features(image_ids, image_paths, db_path):
    dictionary = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_4X4_250)
    parameters =  cv2.aruco.DetectorParameters()
    detector = cv2.aruco.ArucoDetector(dictionary, parameters)
    criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.0001) # Sub-pixel detection

    connection = sqlite3.connect(db_path)
    cursor = connection.cursor()
    cursor.execute("DELETE FROM keypoints;")
    cursor.execute("DELETE FROM descriptors;")
    cursor.execute("DELETE FROM matches;")
    connection.commit()

    logging.info("Extracting features from ChArUco")
    image_id_desc = {}
    for image_id, image_path in tqdm(list(zip(image_ids, image_paths))):
        frame = cv2.imread(image_path)

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        orig_corners, orig_ids, _ = detector.detectMarkers(gray)

        if len(orig_corners) <= 0:
            logging.warning("No markers found in {image_path}")
            continue
        else:
            corners = []
            ids = []
            for (corner, id) in zip(orig_corners, orig_ids):
                area = cv2.contourArea(corner)
                if area >= MARKER_AREA_THRESHOLD:  # PARAM
                    ids.append(id)
                    corners.append(corner)

            if len(orig_corners) - len(corners) > 0:
                logging.warning(f'Ignoring {len(orig_corners) - len(corners)} sliver markers.')

            ids = np.asarray(ids).flatten()
            # ipdb.set_trace()
            uniq, cnt = np.unique(ids, return_counts=True)
            if np.any(cnt > 1):
                if debug:
                    frame_markers = aruco.drawDetectedMarkers(frame.copy(), corners, ids)
                    cv2.imshow("Duplicate markers", frame_markers)
                    ch = cv2.waitKey(0)
                    if ch == 27:
                        exit()
                logging.warning(f"{np.count_nonzero(cnt > 1)} duplicate IDs found, ignoring")

            non_uniq = dict(zip(uniq, cnt))

            uniq_corners = []
            uniq_ids = []
            for i in range(len(corners)):
                # Skip if ID is non-unique
                if non_uniq[ids[i]] > 1:
                    continue

                if np.all(corners[i] >= 0):
                    cv2.cornerSubPix(gray, corners[i], winSize=(3, 3), zeroZone=(-1, -1), criteria=criteria)
                    corners[i] = corners[i].squeeze()
                    uniq_ids.append(ids[i])
                    uniq_corners.append(corners[i])
                else:
                    raise NotImplementedError

            ids = np.asarray(uniq_ids)
            uniq, cnt = np.unique(ids, return_counts=True)

            # Insert keypoints
            if len(uniq_corners) > 0:
                keypoints = np.concatenate(uniq_corners)
                cursor.execute(
                    "INSERT INTO keypoints VALUES (?, ?, ?, ?)",
                    (image_id,) + keypoints.shape + (array_to_blob(keypoints.astype(np.float32)),)
                )

                ids = np.repeat(ids, 4)
                for i in range(4):
                    # TODO: Find a more elegant solution for this
                    ids[i::4] += (i*1000)
                image_id_desc[image_id] = ids

        connection.commit()

    cursor.close()
    connection.close()
    return image_id_desc

def exhaustive_match(image_ids, image_paths, db_path, args, image_id_desc, image_dir):
    connection = sqlite3.connect(db_path)
    cursor = connection.cursor()
    cursor.execute("DELETE FROM matches;")
    connection.commit()

    logging.info("Matching features")
    image_pairs = []
    for i in tqdm(range(len(image_ids))):
        if image_ids[i] not in image_id_desc:
            continue

        for j in range(len(image_ids)):
            if (image_ids[i] >= image_ids[j]) or (image_ids[j] not in image_id_desc):
                continue

            desc1 = image_id_desc[image_ids[i]]
            desc2 = image_id_desc[image_ids[j]]

            # Find matches
            matches = []
            for k in range(desc1.shape[0]):
                for l in range(desc2.shape[0]):
                    if desc1[k] == desc2[l]:
                        matches.append([k, l])

            # Insert into database
            pair_id = image_ids_to_pair_id(image_ids[i], image_ids[j])
            if not matches:
                continue

            image_pairs.append([image_paths[i], image_paths[j]])
            matches = np.asarray(matches, np.uint32)

            cursor.execute("INSERT INTO matches VALUES (?, ?, ?, ?)",
                           (pair_id,) + matches.shape + (array_to_blob(matches),))

            connection.commit()

    cursor.close()
    connection.close()

    match_list_path = os.path.join(tmp_dir, "match_list.txt")
    logging.info(f"Writing image pairs at {match_list_path}")
    with open(os.path.join(match_list_path), "w") as f:
        for pair in image_pairs:
            f.write((" ".join(pair)).replace(image_dir + "/", "") + "\n")

# %%
time_window = np.linspace(60, 110, 100)

for cam_idx in range(2,5):
    fpath = f'videos/CalibrationCam{cam_idx}_03-08-1736_cam{cam_idx}.mp4'

    if os.path.exists(f'calib/cam_{cam_idx}'):
        files = os.listdir(f'calib/cam_{cam_idx}')
        for file in files:
            os.remove(f'calib/cam_{cam_idx}/{file}')
        os.rmdir(f'calib/cam_{cam_idx}')

    os.mkdir(f'calib/cam_{cam_idx}')
    clip = moviepy.editor.VideoFileClip(fpath)
    for image_idx, frame_time in enumerate(time_window):
        clip.save_frame(f'calib/cam_{cam_idx}/image_{image_idx}.jpg', t=frame_time)

# %%
parser = ArgumentParser()
parser.add_argument("-r", "--root_dir", required=True, help="Base directory")
parser.add_argument("--separate_calib", action="store_true")
args = parser.parse_args(['-r', '.'])

db_path = os.path.join(tmp_dir, "db.db")
if args.separate_calib:
    input_image_path = os.path.join(args.root_dir, "image", "synced")
else:
    input_image_path = os.path.join(args.root_dir, "calib")

image_path = os.path.join(tmp_dir, "images")
create_dir(image_path)

image_dirs = list(sorted(glob(f"{input_image_path}/*cam*")))
# Out:
# WARNING:root:Deleting files at tmp/brics_calib/images

# %%
for image_dir in image_dirs:
    # to_copy = os.path.basename(sorted(glob(f"{image_dir}/*.jpg"))[0])
    # os.makedirs(os.path.join(image_path, os.path.basename(image_dir)))
    # shutil.copyfile(os.path.join(image_dir, to_copy),
    #                 os.path.join(image_path, os.path.basename(image_dir), to_copy))
    image_list = sorted(glob(f"{image_dir}/*.jpg"))
    os.makedirs(os.path.join(image_path, os.path.basename(image_dir)))
    for to_copy in image_list:
        to_copy = os.path.basename(to_copy)
        shutil.copyfile(os.path.join(image_dir, to_copy),
                        os.path.join(image_path, os.path.basename(image_dir), to_copy))

if os.path.exists(db_path):
    logging.warning("Previous database found, deleting.")
    os.remove(db_path)
    try:
        os.remove(os.path.join(tmp_dir, "db.db-wal"))
        os.remove(os.path.join(tmp_dir, "db.db-shm"))
    except FileNotFoundError:
        pass

logging.info("Importing images in database")
subprocess.run([
    "colmap", "feature_extractor",
    "--database_path", db_path,
    "--image_path", image_path,
    "--ImageReader.single_camera_per_folder", "1",
    "--ImageReader.camera_model", "OPENCV",
    "--SiftExtraction.use_gpu", "0"]
)

image_ids, image_paths = get_images(args, db_path, input_image_path)
# Out:
# WARNING:root:Deleting files at tmp/brics_calib/images
# WARNING:root:Previous database found, deleting.
# INFO:root:Importing images in database
# ==============================================================================
# Feature extraction
# ==============================================================================
#
# Processed file [1/1500]
#   Name:            cam_2/image_100.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4789
# Processed file [2/1500]
#   Name:            cam_2/image_103.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4654
# Processed file [3/1500]
#   Name:            cam_2/image_101.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4785
# Processed file [4/1500]
#   Name:            cam_2/image_10.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3927
# Processed file [5/1500]
#   Name:            cam_2/image_102.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4700
# Processed file [6/1500]
#   Name:            cam_2/image_0.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4799
# Processed file [7/1500]
#   Name:            cam_2/image_1.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4799
# Processed file [8/1500]
#   Name:            cam_2/image_104.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4968
# Processed file [9/1500]
#   Name:            cam_2/image_106.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4818
# Processed file [10/1500]
#   Name:            cam_2/image_11.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4087
# Processed file [11/1500]
#   Name:            cam_2/image_105.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4875
# Processed file [12/1500]
#   Name:            cam_2/image_109.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4032
# Processed file [13/1500]
#   Name:            cam_2/image_108.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4196
# Processed file [14/1500]
#   Name:            cam_2/image_107.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4439
# Processed file [15/1500]
#   Name:            cam_2/image_110.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3918
# Processed file [16/1500]
#   Name:            cam_2/image_111.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4223
# Processed file [17/1500]
#   Name:            cam_2/image_112.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4217
# Processed file [18/1500]
#   Name:            cam_2/image_114.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4196
# Processed file [19/1500]
#   Name:            cam_2/image_113.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4364
# Processed file [20/1500]
#   Name:            cam_2/image_115.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4484
# Processed file [21/1500]
#   Name:            cam_2/image_117.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4609
# Processed file [22/1500]
#   Name:            cam_2/image_118.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4740
# Processed file [23/1500]
#   Name:            cam_2/image_116.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4547
# Processed file [24/1500]
#   Name:            cam_2/image_119.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4912
# Processed file [25/1500]
#   Name:            cam_2/image_12.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4158
# Processed file [26/1500]
#   Name:            cam_2/image_120.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5032
# Processed file [27/1500]
#   Name:            cam_2/image_121.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5068
# Processed file [28/1500]
#   Name:            cam_2/image_122.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5262
# Processed file [29/1500]
#   Name:            cam_2/image_123.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5168
# Processed file [30/1500]
#   Name:            cam_2/image_126.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5077
# Processed file [31/1500]
#   Name:            cam_2/image_125.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5128
# Processed file [32/1500]
#   Name:            cam_2/image_124.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5238
# Processed file [33/1500]
#   Name:            cam_2/image_128.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5112
# Processed file [34/1500]
#   Name:            cam_2/image_127.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5201
# Processed file [35/1500]
#   Name:            cam_2/image_129.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5533
# Processed file [36/1500]
#   Name:            cam_2/image_13.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4436
# Processed file [37/1500]
#   Name:            cam_2/image_130.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5341
# Processed file [38/1500]
#   Name:            cam_2/image_132.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5222
# Processed file [39/1500]
#   Name:            cam_2/image_131.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5220
# Processed file [40/1500]
#   Name:            cam_2/image_133.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5217
# Processed file [41/1500]
#   Name:            cam_2/image_134.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5258
# Processed file [42/1500]
#   Name:            cam_2/image_136.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5976
# Processed file [43/1500]
#   Name:            cam_2/image_135.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5328
# Processed file [44/1500]
#   Name:            cam_2/image_137.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5898
# Processed file [45/1500]
#   Name:            cam_2/image_138.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5811
# Processed file [46/1500]
#   Name:            cam_2/image_14.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4314
# Processed file [47/1500]
#   Name:            cam_2/image_139.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5558
# Processed file [48/1500]
#   Name:            cam_2/image_140.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5347
# Processed file [49/1500]
#   Name:            cam_2/image_141.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5296
# Processed file [50/1500]
#   Name:            cam_2/image_142.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5278
# Processed file [51/1500]
#   Name:            cam_2/image_143.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5807
# Processed file [52/1500]
#   Name:            cam_2/image_144.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5800
# Processed file [53/1500]
#   Name:            cam_2/image_146.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5663
# Processed file [54/1500]
#   Name:            cam_2/image_145.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5808
# Processed file [55/1500]
#   Name:            cam_2/image_148.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5388
# Processed file [56/1500]
#   Name:            cam_2/image_147.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5461
# Processed file [57/1500]
#   Name:            cam_2/image_149.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5145
# Processed file [58/1500]
#   Name:            cam_2/image_15.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4348
# Processed file [59/1500]
#   Name:            cam_2/image_150.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4512
# Processed file [60/1500]
#   Name:            cam_2/image_151.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4553
# Processed file [61/1500]
#   Name:            cam_2/image_152.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4553
# Processed file [62/1500]
#   Name:            cam_2/image_153.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4502
# Processed file [63/1500]
#   Name:            cam_2/image_155.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4548
# Processed file [64/1500]
#   Name:            cam_2/image_154.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4420
# Processed file [65/1500]
#   Name:            cam_2/image_156.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4722
# Processed file [66/1500]
#   Name:            cam_2/image_159.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4876
# Processed file [67/1500]
#   Name:            cam_2/image_157.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4882
# Processed file [68/1500]
#   Name:            cam_2/image_158.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4966
# Processed file [69/1500]
#   Name:            cam_2/image_16.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4478
# Processed file [70/1500]
#   Name:            cam_2/image_160.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4748
# Processed file [71/1500]
#   Name:            cam_2/image_161.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4614
# Processed file [72/1500]
#   Name:            cam_2/image_162.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4485
# Processed file [73/1500]
#   Name:            cam_2/image_163.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4548
# Processed file [74/1500]
#   Name:            cam_2/image_166.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4386
# Processed file [75/1500]
#   Name:            cam_2/image_165.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4406
# Processed file [76/1500]
#   Name:            cam_2/image_164.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4398
# Processed file [77/1500]
#   Name:            cam_2/image_167.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4438
# Processed file [78/1500]
#   Name:            cam_2/image_168.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4215
# Processed file [79/1500]
#   Name:            cam_2/image_169.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4133
# Processed file [80/1500]
#   Name:            cam_2/image_17.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4638
# Processed file [81/1500]
#   Name:            cam_2/image_170.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4309
# Processed file [82/1500]
#   Name:            cam_2/image_172.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4943
# Processed file [83/1500]
#   Name:            cam_2/image_171.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4532
# Processed file [84/1500]
#   Name:            cam_2/image_173.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4966
# Processed file [85/1500]
#   Name:            cam_2/image_174.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4817
# Processed file [86/1500]
#   Name:            cam_2/image_175.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4667
# Processed file [87/1500]
#   Name:            cam_2/image_177.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4647
# Processed file [88/1500]
#   Name:            cam_2/image_176.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4745
# Processed file [89/1500]
#   Name:            cam_2/image_178.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4689
# Processed file [90/1500]
#   Name:            cam_2/image_179.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4988
# Processed file [91/1500]
#   Name:            cam_2/image_18.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4928
# Processed file [92/1500]
#   Name:            cam_2/image_180.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5112
# Processed file [93/1500]
#   Name:            cam_2/image_182.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5130
# Processed file [94/1500]
#   Name:            cam_2/image_181.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5108
# Processed file [95/1500]
#   Name:            cam_2/image_183.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5244
# Processed file [96/1500]
#   Name:            cam_2/image_184.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5097
# Processed file [97/1500]
#   Name:            cam_2/image_185.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4852
# Processed file [98/1500]
#   Name:            cam_2/image_186.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4296
# Processed file [99/1500]
#   Name:            cam_2/image_187.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4589
# Processed file [100/1500]
#   Name:            cam_2/image_188.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4543
# Processed file [101/1500]
#   Name:            cam_2/image_189.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4566
# Processed file [102/1500]
#   Name:            cam_2/image_19.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4925
# Processed file [103/1500]
#   Name:            cam_2/image_190.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4536
# Processed file [104/1500]
#   Name:            cam_2/image_191.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4520
# Processed file [105/1500]
#   Name:            cam_2/image_192.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4721
# Processed file [106/1500]
#   Name:            cam_2/image_193.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4807
# Processed file [107/1500]
#   Name:            cam_2/image_194.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4888
# Processed file [108/1500]
#   Name:            cam_2/image_195.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4920
# Processed file [109/1500]
#   Name:            cam_2/image_196.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4814
# Processed file [110/1500]
#   Name:            cam_2/image_197.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4978
# Processed file [111/1500]
#   Name:            cam_2/image_198.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4995
# Processed file [112/1500]
#   Name:            cam_2/image_199.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5054
# Processed file [113/1500]
#   Name:            cam_2/image_20.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4852
# Processed file [114/1500]
#   Name:            cam_2/image_2.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4909
# Processed file [115/1500]
#   Name:            cam_2/image_200.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5051
# Processed file [116/1500]
#   Name:            cam_2/image_202.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5001
# Processed file [117/1500]
#   Name:            cam_2/image_201.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5060
# Processed file [118/1500]
#   Name:            cam_2/image_204.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4890
# Processed file [119/1500]
#   Name:            cam_2/image_203.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4966
# Processed file [120/1500]
#   Name:            cam_2/image_205.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4840
# Processed file [121/1500]
#   Name:            cam_2/image_206.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4854
# Processed file [122/1500]
#   Name:            cam_2/image_208.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4834
# Processed file [123/1500]
#   Name:            cam_2/image_209.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4736
# Processed file [124/1500]
#   Name:            cam_2/image_207.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4782
# Processed file [125/1500]
#   Name:            cam_2/image_21.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4943
# Processed file [126/1500]
#   Name:            cam_2/image_211.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4676
# Processed file [127/1500]
#   Name:            cam_2/image_210.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4768
# Processed file [128/1500]
#   Name:            cam_2/image_212.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4718
# Processed file [129/1500]
#   Name:            cam_2/image_214.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4604
# Processed file [130/1500]
#   Name:            cam_2/image_213.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4661
# Processed file [131/1500]
#   Name:            cam_2/image_216.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4512
# Processed file [132/1500]
#   Name:            cam_2/image_217.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4532
# Processed file [133/1500]
#   Name:            cam_2/image_215.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4399
# Processed file [134/1500]
#   Name:            cam_2/image_218.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4533
# Processed file [135/1500]
#   Name:            cam_2/image_219.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4646
# Processed file [136/1500]
#   Name:            cam_2/image_22.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4894
# Processed file [137/1500]
#   Name:            cam_2/image_220.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4805
# Processed file [138/1500]
#   Name:            cam_2/image_221.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4967
# Processed file [139/1500]
#   Name:            cam_2/image_222.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5912
# Processed file [140/1500]
#   Name:            cam_2/image_223.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5874
# Processed file [141/1500]
#   Name:            cam_2/image_225.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5596
# Processed file [142/1500]
#   Name:            cam_2/image_224.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5788
# Processed file [143/1500]
#   Name:            cam_2/image_226.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5566
# Processed file [144/1500]
#   Name:            cam_2/image_227.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5532
# Processed file [145/1500]
#   Name:            cam_2/image_228.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5593
# Processed file [146/1500]
#   Name:            cam_2/image_23.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4893
# Processed file [147/1500]
#   Name:            cam_2/image_229.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5369
# Processed file [148/1500]
#   Name:            cam_2/image_230.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5076
# Processed file [149/1500]
#   Name:            cam_2/image_231.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4975
# Processed file [150/1500]
#   Name:            cam_2/image_232.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4938
# Processed file [151/1500]
#   Name:            cam_2/image_233.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4918
# Processed file [152/1500]
#   Name:            cam_2/image_234.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4814
# Processed file [153/1500]
#   Name:            cam_2/image_235.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4842
# Processed file [154/1500]
#   Name:            cam_2/image_236.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4923
# Processed file [155/1500]
#   Name:            cam_2/image_238.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5002
# Processed file [156/1500]
#   Name:            cam_2/image_237.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5112
# Processed file [157/1500]
#   Name:            cam_2/image_24.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4778
# Processed file [158/1500]
#   Name:            cam_2/image_239.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4919
# Processed file [159/1500]
#   Name:            cam_2/image_240.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4861
# Processed file [160/1500]
#   Name:            cam_2/image_241.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4724
# Processed file [161/1500]
#   Name:            cam_2/image_242.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4658
# Processed file [162/1500]
#   Name:            cam_2/image_243.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4647
# Processed file [163/1500]
#   Name:            cam_2/image_244.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4582
# Processed file [164/1500]
#   Name:            cam_2/image_245.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4544
# Processed file [165/1500]
#   Name:            cam_2/image_247.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4368
# Processed file [166/1500]
#   Name:            cam_2/image_246.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4471
# Processed file [167/1500]
#   Name:            cam_2/image_249.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4640
# Processed file [168/1500]
#   Name:            cam_2/image_248.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4440
# Processed file [169/1500]
#   Name:            cam_2/image_251.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4499
# Processed file [170/1500]
#   Name:            cam_2/image_25.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4639
# Processed file [171/1500]
#   Name:            cam_2/image_252.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4578
# Processed file [172/1500]
#   Name:            cam_2/image_250.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4554
# Processed file [173/1500]
#   Name:            cam_2/image_254.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4444
# Processed file [174/1500]
#   Name:            cam_2/image_255.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4510
# Processed file [175/1500]
#   Name:            cam_2/image_253.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4466
# Processed file [176/1500]
#   Name:            cam_2/image_256.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4631
# Processed file [177/1500]
#   Name:            cam_2/image_259.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4253
# Processed file [178/1500]
#   Name:            cam_2/image_257.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4667
# Processed file [179/1500]
#   Name:            cam_2/image_26.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4543
# Processed file [180/1500]
#   Name:            cam_2/image_258.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4503
# Processed file [181/1500]
#   Name:            cam_2/image_260.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4035
# Processed file [182/1500]
#   Name:            cam_2/image_261.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4076
# Processed file [183/1500]
#   Name:            cam_2/image_262.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4135
# Processed file [184/1500]
#   Name:            cam_2/image_263.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4219
# Processed file [185/1500]
#   Name:            cam_2/image_265.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4501
# Processed file [186/1500]
#   Name:            cam_2/image_264.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4427
# Processed file [187/1500]
#   Name:            cam_2/image_269.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4396
# Processed file [188/1500]
#   Name:            cam_2/image_268.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4637
# Processed file [189/1500]
#   Name:            cam_2/image_266.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4699
# Processed file [190/1500]
#   Name:            cam_2/image_267.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4579
# Processed file [191/1500]
#   Name:            cam_2/image_27.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4654
# Processed file [192/1500]
#   Name:            cam_2/image_270.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4444
# Processed file [193/1500]
#   Name:            cam_2/image_271.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4545
# Processed file [194/1500]
#   Name:            cam_2/image_272.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4542
# Processed file [195/1500]
#   Name:            cam_2/image_273.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4961
# Processed file [196/1500]
#   Name:            cam_2/image_275.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5005
# Processed file [197/1500]
#   Name:            cam_2/image_274.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4979
# Processed file [198/1500]
#   Name:            cam_2/image_276.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5078
# Processed file [199/1500]
#   Name:            cam_2/image_277.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5109
# Processed file [200/1500]
#   Name:            cam_2/image_278.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5259
# Processed file [201/1500]
#   Name:            cam_2/image_28.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5072
# Processed file [202/1500]
#   Name:            cam_2/image_279.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5386
# Processed file [203/1500]
#   Name:            cam_2/image_280.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4905
# Processed file [204/1500]
#   Name:            cam_2/image_281.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4809
# Processed file [205/1500]
#   Name:            cam_2/image_282.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4787
# Processed file [206/1500]
#   Name:            cam_2/image_283.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4907
# Processed file [207/1500]
#   Name:            cam_2/image_284.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5021
# Processed file [208/1500]
#   Name:            cam_2/image_285.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5042
# Processed file [209/1500]
#   Name:            cam_2/image_286.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5117
# Processed file [210/1500]
#   Name:            cam_2/image_289.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5355
# Processed file [211/1500]
#   Name:            cam_2/image_288.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5361
# Processed file [212/1500]
#   Name:            cam_2/image_287.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5265
# Processed file [213/1500]
#   Name:            cam_2/image_29.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4928
# Processed file [214/1500]
#   Name:            cam_2/image_291.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5332
# Processed file [215/1500]
#   Name:            cam_2/image_290.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5357
# Processed file [216/1500]
#   Name:            cam_2/image_292.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5304
# Processed file [217/1500]
#   Name:            cam_2/image_293.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5227
# Processed file [218/1500]
#   Name:            cam_2/image_295.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4952
# Processed file [219/1500]
#   Name:            cam_2/image_294.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4855
# Processed file [220/1500]
#   Name:            cam_2/image_297.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4872
# Processed file [221/1500]
#   Name:            cam_2/image_298.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4890
# Processed file [222/1500]
#   Name:            cam_2/image_299.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4912
# Processed file [223/1500]
#   Name:            cam_2/image_296.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4906
# Processed file [224/1500]
#   Name:            cam_2/image_3.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5022
# Processed file [225/1500]
#   Name:            cam_2/image_30.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4802
# Processed file [226/1500]
#   Name:            cam_2/image_300.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4969
# Processed file [227/1500]
#   Name:            cam_2/image_301.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4884
# Processed file [228/1500]
#   Name:            cam_2/image_302.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5154
# Processed file [229/1500]
#   Name:            cam_2/image_303.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4986
# Processed file [230/1500]
#   Name:            cam_2/image_304.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4811
# Processed file [231/1500]
#   Name:            cam_2/image_305.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4618
# Processed file [232/1500]
#   Name:            cam_2/image_306.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4535
# Processed file [233/1500]
#   Name:            cam_2/image_308.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4429
# Processed file [234/1500]
#   Name:            cam_2/image_307.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4385
# Processed file [235/1500]
#   Name:            cam_2/image_309.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4506
# Processed file [236/1500]
#   Name:            cam_2/image_31.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4684
# Processed file [237/1500]
#   Name:            cam_2/image_311.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4315
# Processed file [238/1500]
#   Name:            cam_2/image_312.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4302
# Processed file [239/1500]
#   Name:            cam_2/image_313.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4271
# Processed file [240/1500]
#   Name:            cam_2/image_310.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4413
# Processed file [241/1500]
#   Name:            cam_2/image_314.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4319
# Processed file [242/1500]
#   Name:            cam_2/image_315.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4452
# Processed file [243/1500]
#   Name:            cam_2/image_316.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4486
# Processed file [244/1500]
#   Name:            cam_2/image_317.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4299
# Processed file [245/1500]
#   Name:            cam_2/image_319.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4185
# Processed file [246/1500]
#   Name:            cam_2/image_318.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4284
# Processed file [247/1500]
#   Name:            cam_2/image_320.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4330
# Processed file [248/1500]
#   Name:            cam_2/image_32.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4727
# Processed file [249/1500]
#   Name:            cam_2/image_321.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4513
# Processed file [250/1500]
#   Name:            cam_2/image_322.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4631
# Processed file [251/1500]
#   Name:            cam_2/image_323.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5190
# Processed file [252/1500]
#   Name:            cam_2/image_324.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        5072
# Processed file [253/1500]
#   Name:            cam_2/image_325.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4952
# Processed file [254/1500]
#   Name:            cam_2/image_326.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4709
# Processed file [255/1500]
#   Name:            cam_2/image_327.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4716
# Processed file [256/1500]
#   Name:            cam_2/image_328.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4681
# Processed file [257/1500]
#   Name:            cam_2/image_329.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4854
# Processed file [258/1500]
#   Name:            cam_2/image_33.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4717
# Processed file [259/1500]
#   Name:            cam_2/image_330.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4876
# Processed file [260/1500]
#   Name:            cam_2/image_332.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4620
# Processed file [261/1500]
#   Name:            cam_2/image_331.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4668
# Processed file [262/1500]
#   Name:            cam_2/image_333.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4654
# Processed file [263/1500]
#   Name:            cam_2/image_334.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4848
# Processed file [264/1500]
#   Name:            cam_2/image_335.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4867
# Processed file [265/1500]
#   Name:            cam_2/image_336.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #1 - OPENCV
#   Focal Length:    1728.00px
#   Features:        4658
# Processed file [266/1500]
#   Name:            cam_2/image_337.jpg
#   Dimensions:      1440 x 1056
# ...
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2679
# Processed file [1413/1500]
#   Name:            cam_4/image_47.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3463
# Processed file [1414/1500]
#   Name:            cam_4/image_472.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2795
# Processed file [1415/1500]
#   Name:            cam_4/image_471.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2739
# Processed file [1416/1500]
#   Name:            cam_4/image_470.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2689
# Processed file [1417/1500]
#   Name:            cam_4/image_473.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2780
# Processed file [1418/1500]
#   Name:            cam_4/image_474.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2799
# Processed file [1419/1500]
#   Name:            cam_4/image_475.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2671
# Processed file [1420/1500]
#   Name:            cam_4/image_476.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2737
# Processed file [1421/1500]
#   Name:            cam_4/image_477.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2695
# Processed file [1422/1500]
#   Name:            cam_4/image_478.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2784
# Processed file [1423/1500]
#   Name:            cam_4/image_48.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3492
# Processed file [1424/1500]
#   Name:            cam_4/image_480.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2662
# Processed file [1425/1500]
#   Name:            cam_4/image_479.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2753
# Processed file [1426/1500]
#   Name:            cam_4/image_482.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2576
# Processed file [1427/1500]
#   Name:            cam_4/image_481.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2640
# Processed file [1428/1500]
#   Name:            cam_4/image_483.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2644
# Processed file [1429/1500]
#   Name:            cam_4/image_484.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2613
# Processed file [1430/1500]
#   Name:            cam_4/image_485.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2422
# Processed file [1431/1500]
#   Name:            cam_4/image_487.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        1906
# Processed file [1432/1500]
#   Name:            cam_4/image_486.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2097
# Processed file [1433/1500]
#   Name:            cam_4/image_488.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        1665
# Processed file [1434/1500]
#   Name:            cam_4/image_489.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        1380
# Processed file [1435/1500]
#   Name:            cam_4/image_49.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3451
# Processed file [1436/1500]
#   Name:            cam_4/image_490.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        1312
# Processed file [1437/1500]
#   Name:            cam_4/image_492.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        1429
# Processed file [1438/1500]
#   Name:            cam_4/image_491.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        1365
# Processed file [1439/1500]
#   Name:            cam_4/image_493.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        1484
# Processed file [1440/1500]
#   Name:            cam_4/image_495.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        1530
# Processed file [1441/1500]
#   Name:            cam_4/image_494.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        1476
# Processed file [1442/1500]
#   Name:            cam_4/image_496.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        1417
# Processed file [1443/1500]
#   Name:            cam_4/image_497.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        1462
# Processed file [1444/1500]
#   Name:            cam_4/image_498.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        1474
# Processed file [1445/1500]
#   Name:            cam_4/image_499.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        1478
# Processed file [1446/1500]
#   Name:            cam_4/image_50.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3671
# Processed file [1447/1500]
#   Name:            cam_4/image_5.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3010
# Processed file [1448/1500]
#   Name:            cam_4/image_52.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3505
# Processed file [1449/1500]
#   Name:            cam_4/image_51.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3555
# Processed file [1450/1500]
#   Name:            cam_4/image_54.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3518
# Processed file [1451/1500]
#   Name:            cam_4/image_53.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3491
# Processed file [1452/1500]
#   Name:            cam_4/image_55.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3474
# Processed file [1453/1500]
#   Name:            cam_4/image_56.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3524
# Processed file [1454/1500]
#   Name:            cam_4/image_57.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3868
# Processed file [1455/1500]
#   Name:            cam_4/image_58.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3606
# Processed file [1456/1500]
#   Name:            cam_4/image_59.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3418
# Processed file [1457/1500]
#   Name:            cam_4/image_6.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2868
# Processed file [1458/1500]
#   Name:            cam_4/image_60.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3383
# Processed file [1459/1500]
#   Name:            cam_4/image_61.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3410
# Processed file [1460/1500]
#   Name:            cam_4/image_62.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3417
# Processed file [1461/1500]
#   Name:            cam_4/image_63.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3476
# Processed file [1462/1500]
#   Name:            cam_4/image_64.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3779
# Processed file [1463/1500]
#   Name:            cam_4/image_66.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3579
# Processed file [1464/1500]
#   Name:            cam_4/image_65.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3673
# Processed file [1465/1500]
#   Name:            cam_4/image_67.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3576
# Processed file [1466/1500]
#   Name:            cam_4/image_68.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3610
# Processed file [1467/1500]
#   Name:            cam_4/image_69.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3652
# Processed file [1468/1500]
#   Name:            cam_4/image_7.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2794
# Processed file [1469/1500]
#   Name:            cam_4/image_70.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3634
# Processed file [1470/1500]
#   Name:            cam_4/image_71.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3946
# Processed file [1471/1500]
#   Name:            cam_4/image_72.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3934
# Processed file [1472/1500]
#   Name:            cam_4/image_75.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3807
# Processed file [1473/1500]
#   Name:            cam_4/image_73.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3935
# Processed file [1474/1500]
#   Name:            cam_4/image_74.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3853
# Processed file [1475/1500]
#   Name:            cam_4/image_77.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3712
# Processed file [1476/1500]
#   Name:            cam_4/image_76.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3775
# Processed file [1477/1500]
#   Name:            cam_4/image_78.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3643
# Processed file [1478/1500]
#   Name:            cam_4/image_79.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3688
# Processed file [1479/1500]
#   Name:            cam_4/image_8.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        2874
# Processed file [1480/1500]
#   Name:            cam_4/image_80.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3659
# Processed file [1481/1500]
#   Name:            cam_4/image_82.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3730
# Processed file [1482/1500]
#   Name:            cam_4/image_81.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3669
# Processed file [1483/1500]
#   Name:            cam_4/image_83.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3641
# Processed file [1484/1500]
#   Name:            cam_4/image_84.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3491
# Processed file [1485/1500]
#   Name:            cam_4/image_85.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3366
# Processed file [1486/1500]
#   Name:            cam_4/image_86.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3435
# Processed file [1487/1500]
#   Name:            cam_4/image_87.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3305
# Processed file [1488/1500]
#   Name:            cam_4/image_88.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3301
# Processed file [1489/1500]
#   Name:            cam_4/image_9.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3075
# Processed file [1490/1500]
#   Name:            cam_4/image_89.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3175
# Processed file [1491/1500]
#   Name:            cam_4/image_90.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3227
# Processed file [1492/1500]
#   Name:            cam_4/image_91.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3260
# Processed file [1493/1500]
#   Name:            cam_4/image_92.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3279
# Processed file [1494/1500]
#   Name:            cam_4/image_93.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3605
# Processed file [1495/1500]
#   Name:            cam_4/image_94.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3713
# Processed file [1496/1500]
#   Name:            cam_4/image_95.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3636
# Processed file [1497/1500]
#   Name:            cam_4/image_96.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3702
# Processed file [1498/1500]
#   Name:            cam_4/image_97.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3795
# Processed file [1499/1500]
#   Name:            cam_4/image_98.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3765
# Processed file [1500/1500]
#   Name:            cam_4/image_99.jpg
#   Dimensions:      1440 x 1056
#   Camera:          #3 - OPENCV
#   Focal Length:    1728.00px
#   Features:        3674
# Elapsed time: 23.107 [minutes]

# %%
image_id_desc = add_features(image_ids, image_paths, db_path)
# Out:
# INFO:root:Extracting features from ChArUco
#   0%|          | 0/1500 [00:00<?, ?it/s]WARNING:root:Ignoring 8 sliver markers.
# WARNING:root:Ignoring 9 sliver markers.
# WARNING:root:No markers found in {image_path}
#   0%|          | 3/1500 [00:00<01:06, 22.61it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#   0%|          | 6/1500 [00:00<00:58, 25.42it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#   1%|          | 9/1500 [00:00<00:55, 26.73it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#   1%|          | 13/1500 [00:00<00:50, 29.50it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#   1%|          | 17/1500 [00:00<00:49, 30.10it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 3 sliver markers.
# WARNING:root:Ignoring 2 sliver markers.
# WARNING:root:Ignoring 1 sliver markers.
#   1%|▏         | 21/1500 [00:00<00:48, 30.34it/s]WARNING:root:Ignoring 5 sliver markers.
# WARNING:root:Ignoring 4 sliver markers.
# WARNING:root:Ignoring 8 sliver markers.
# WARNING:root:No markers found in {image_path}
#   2%|▏         | 25/1500 [00:00<00:48, 30.63it/s]WARNING:root:Ignoring 10 sliver markers.
# WARNING:root:Ignoring 14 sliver markers.
# WARNING:root:Ignoring 14 sliver markers.
# WARNING:root:Ignoring 11 sliver markers.
#   2%|▏         | 29/1500 [00:00<00:48, 30.05it/s]WARNING:root:Ignoring 9 sliver markers.
# WARNING:root:Ignoring 9 sliver markers.
# WARNING:root:Ignoring 9 sliver markers.
# WARNING:root:Ignoring 13 sliver markers.
#   2%|▏         | 33/1500 [00:01<00:48, 30.41it/s]WARNING:root:Ignoring 12 sliver markers.
# WARNING:root:Ignoring 15 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 10 sliver markers.
#   2%|▏         | 37/1500 [00:01<00:48, 29.97it/s]WARNING:root:Ignoring 6 sliver markers.
# WARNING:root:Ignoring 12 sliver markers.
# WARNING:root:Ignoring 8 sliver markers.
# WARNING:root:Ignoring 13 sliver markers.
#   3%|▎         | 41/1500 [00:01<00:48, 30.19it/s]WARNING:root:Ignoring 12 sliver markers.
# WARNING:root:Ignoring 13 sliver markers.
# WARNING:root:Ignoring 16 sliver markers.
# WARNING:root:Ignoring 14 sliver markers.
#   3%|▎         | 45/1500 [00:01<00:47, 30.77it/s]WARNING:root:Ignoring 11 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 12 sliver markers.
# WARNING:root:Ignoring 14 sliver markers.
#   3%|▎         | 49/1500 [00:01<00:46, 31.08it/s]WARNING:root:Ignoring 11 sliver markers.
# WARNING:root:Ignoring 16 sliver markers.
# WARNING:root:Ignoring 15 sliver markers.
# WARNING:root:Ignoring 10 sliver markers.
#   4%|▎         | 53/1500 [00:01<00:47, 30.37it/s]WARNING:root:Ignoring 13 sliver markers.
# WARNING:root:Ignoring 11 sliver markers.
# WARNING:root:Ignoring 8 sliver markers.
# WARNING:root:Ignoring 7 sliver markers.
#   4%|▍         | 57/1500 [00:01<00:46, 30.77it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#   4%|▍         | 61/1500 [00:02<00:44, 32.46it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#   4%|▍         | 65/1500 [00:02<00:43, 32.67it/s]WARNING:root:Ignoring 2 sliver markers.
# WARNING:root:Ignoring 2 sliver markers.
# WARNING:root:Ignoring 1 sliver markers.
# WARNING:root:No markers found in {image_path}
#   5%|▍         | 69/1500 [00:02<00:43, 32.99it/s]WARNING:root:Ignoring 1 sliver markers.
# WARNING:root:Ignoring 1 sliver markers.
# WARNING:root:Ignoring 1 sliver markers.
# WARNING:root:No markers found in {image_path}
#   5%|▍         | 73/1500 [00:02<00:43, 32.94it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#   5%|▌         | 77/1500 [00:02<00:42, 33.26it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 1 sliver markers.
# WARNING:root:No markers found in {image_path}
#   5%|▌         | 81/1500 [00:02<00:42, 33.19it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#   6%|▌         | 85/1500 [00:02<00:43, 32.80it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#   6%|▌         | 89/1500 [00:02<00:43, 32.26it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 4 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#   6%|▌         | 93/1500 [00:02<00:43, 31.99it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#   6%|▋         | 97/1500 [00:03<00:43, 32.17it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#   7%|▋         | 101/1500 [00:03<00:44, 31.67it/s]WARNING:root:Ignoring 4 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#   7%|▋         | 105/1500 [00:03<00:44, 31.43it/s]WARNING:root:Ignoring 2 sliver markers.
# WARNING:root:Ignoring 15 sliver markers.
# WARNING:root:Ignoring 10 sliver markers.
# WARNING:root:Ignoring 7 sliver markers.
#   7%|▋         | 109/1500 [00:03<00:44, 31.26it/s]WARNING:root:Ignoring 12 sliver markers.
# WARNING:root:Ignoring 11 sliver markers.
# WARNING:root:Ignoring 15 sliver markers.
# WARNING:root:Ignoring 8 sliver markers.
#   8%|▊         | 113/1500 [00:03<00:44, 31.28it/s]WARNING:root:Ignoring 8 sliver markers.
# WARNING:root:Ignoring 12 sliver markers.
# WARNING:root:Ignoring 15 sliver markers.
# WARNING:root:Ignoring 9 sliver markers.
#   8%|▊         | 117/1500 [00:03<00:45, 30.68it/s]WARNING:root:Ignoring 7 sliver markers.
# WARNING:root:Ignoring 8 sliver markers.
# WARNING:root:Ignoring 5 sliver markers.
# WARNING:root:Ignoring 7 sliver markers.
#   8%|▊         | 121/1500 [00:03<00:45, 30.23it/s]WARNING:root:Ignoring 9 sliver markers.
# WARNING:root:Ignoring 12 sliver markers.
# WARNING:root:Ignoring 12 sliver markers.
# WARNING:root:Ignoring 15 sliver markers.
#   8%|▊         | 125/1500 [00:04<00:46, 29.66it/s]WARNING:root:Ignoring 11 sliver markers.
# WARNING:root:Ignoring 16 sliver markers.
# WARNING:root:Ignoring 16 sliver markers.
#   9%|▊         | 128/1500 [00:04<00:46, 29.36it/s]WARNING:root:Ignoring 10 sliver markers.
# WARNING:root:Ignoring 11 sliver markers.
# WARNING:root:Ignoring 4 sliver markers.
# WARNING:root:Ignoring 3 sliver markers.
#   9%|▉         | 132/1500 [00:04<00:45, 29.77it/s]WARNING:root:Ignoring 5 sliver markers.
# WARNING:root:Ignoring 4 sliver markers.
# WARNING:root:Ignoring 3 sliver markers.
#   9%|▉         | 135/1500 [00:04<00:46, 29.52it/s]WARNING:root:Ignoring 13 sliver markers.
# WARNING:root:Ignoring 4 sliver markers.
# WARNING:root:Ignoring 10 sliver markers.
# WARNING:root:Ignoring 17 sliver markers.
#   9%|▉         | 139/1500 [00:04<00:45, 29.97it/s]WARNING:root:Ignoring 13 sliver markers.
# WARNING:root:Ignoring 13 sliver markers.
# WARNING:root:Ignoring 17 sliver markers.
#   9%|▉         | 142/1500 [00:04<00:45, 29.55it/s]WARNING:root:Ignoring 13 sliver markers.
# WARNING:root:Ignoring 18 sliver markers.
# WARNING:root:Ignoring 15 sliver markers.
#  10%|▉         | 145/1500 [00:04<00:45, 29.63it/s]WARNING:root:Ignoring 12 sliver markers.
# WARNING:root:Ignoring 9 sliver markers.
# WARNING:root:Ignoring 11 sliver markers.
sliver markers.
# WARNING:root:Ignoring 5 sliver markers.
#  20%|██        | 303/1500 [00:09<00:36, 32.69it/s]WARNING:root:Ignoring 5 sliver markers.
# WARNING:root:Ignoring 10 sliver markers.
# WARNING:root:Ignoring 8 sliver markers.
# WARNING:root:Ignoring 13 sliver markers.
#  20%|██        | 307/1500 [00:09<00:35, 33.25it/s]WARNING:root:Ignoring 15 sliver markers.
# WARNING:root:Ignoring 11 sliver markers.
# WARNING:root:Ignoring 14 sliver markers.
# WARNING:root:Ignoring 17 sliver markers.
#  21%|██        | 311/1500 [00:09<00:35, 33.20it/s]WARNING:root:Ignoring 16 sliver markers.
# WARNING:root:Ignoring 16 sliver markers.
# WARNING:root:Ignoring 16 sliver markers.
# WARNING:root:Ignoring 17 sliver markers.
#  21%|██        | 315/1500 [00:10<00:37, 31.94it/s]WARNING:root:Ignoring 12 sliver markers.
# WARNING:root:Ignoring 8 sliver markers.
# WARNING:root:Ignoring 14 sliver markers.
# WARNING:root:Ignoring 18 sliver markers.
#  21%|██▏       | 319/1500 [00:10<00:36, 32.13it/s]WARNING:root:Ignoring 18 sliver markers.
# WARNING:root:Ignoring 20 sliver markers.
# WARNING:root:Ignoring 21 sliver markers.
# WARNING:root:Ignoring 23 sliver markers.
#  22%|██▏       | 323/1500 [00:10<00:36, 32.26it/s]WARNING:root:Ignoring 12 sliver markers.
# WARNING:root:Ignoring 22 sliver markers.
# WARNING:root:Ignoring 19 sliver markers.
# WARNING:root:Ignoring 21 sliver markers.
#  22%|██▏       | 327/1500 [00:10<00:36, 31.93it/s]WARNING:root:Ignoring 9 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 2 sliver markers.
#  22%|██▏       | 331/1500 [00:10<00:36, 31.68it/s]WARNING:root:Ignoring 1 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 1 sliver markers.
# WARNING:root:Ignoring 12 sliver markers.
#  22%|██▏       | 335/1500 [00:10<00:37, 31.45it/s]WARNING:root:Ignoring 7 sliver markers.
# WARNING:root:Ignoring 3 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  23%|██▎       | 339/1500 [00:10<00:36, 31.71it/s]WARNING:root:Ignoring 2 sliver markers.
# WARNING:root:Ignoring 1 sliver markers.
# WARNING:root:Ignoring 1 sliver markers.
# WARNING:root:Ignoring 1 sliver markers.
#  23%|██▎       | 343/1500 [00:10<00:36, 31.68it/s]WARNING:root:Ignoring 2 sliver markers.
# WARNING:root:Ignoring 2 sliver markers.
# WARNING:root:Ignoring 1 sliver markers.
# WARNING:root:Ignoring 5 sliver markers.
#  23%|██▎       | 347/1500 [00:11<00:36, 31.75it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  23%|██▎       | 351/1500 [00:11<00:35, 32.55it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 3 sliver markers.
# WARNING:root:Ignoring 3 sliver markers.
# WARNING:root:Ignoring 7 sliver markers.
#  24%|██▎       | 355/1500 [00:11<00:35, 32.22it/s]WARNING:root:Ignoring 9 sliver markers.
# WARNING:root:Ignoring 12 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 22 sliver markers.
#  24%|██▍       | 359/1500 [00:11<00:35, 32.37it/s]WARNING:root:Ignoring 21 sliver markers.
# WARNING:root:Ignoring 20 sliver markers.
# WARNING:root:Ignoring 23 sliver markers.
# WARNING:root:Ignoring 27 sliver markers.
#  24%|██▍       | 363/1500 [00:11<00:36, 31.05it/s]WARNING:root:Ignoring 23 sliver markers.
# WARNING:root:Ignoring 24 sliver markers.
# WARNING:root:Ignoring 26 sliver markers.
# WARNING:root:Ignoring 22 sliver markers.
#  24%|██▍       | 367/1500 [00:11<00:38, 29.77it/s]WARNING:root:Ignoring 23 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 22 sliver markers.
# WARNING:root:Ignoring 23 sliver markers.
#  25%|██▍       | 371/1500 [00:11<00:37, 29.71it/s]WARNING:root:Ignoring 19 sliver markers.
# WARNING:root:Ignoring 22 sliver markers.
# WARNING:root:Ignoring 26 sliver markers.
# WARNING:root:Ignoring 27 sliver markers.
#  25%|██▌       | 375/1500 [00:12<00:36, 30.62it/s]WARNING:root:Ignoring 23 sliver markers.
# WARNING:root:Ignoring 26 sliver markers.
# WARNING:root:Ignoring 22 sliver markers.
# WARNING:root:Ignoring 18 sliver markers.
#  25%|██▌       | 379/1500 [00:12<00:35, 31.77it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 20 sliver markers.
# WARNING:root:Ignoring 17 sliver markers.
# WARNING:root:Ignoring 19 sliver markers.
#  26%|██▌       | 383/1500 [00:12<00:33, 33.55it/s]WARNING:root:Ignoring 20 sliver markers.
# WARNING:root:Ignoring 20 sliver markers.
# WARNING:root:Ignoring 22 sliver markers.
# WARNING:root:Ignoring 23 sliver markers.
#  26%|██▌       | 387/1500 [00:12<00:32, 33.91it/s]WARNING:root:Ignoring 21 sliver markers.
# WARNING:root:Ignoring 25 sliver markers.
# WARNING:root:Ignoring 22 sliver markers.
# WARNING:root:No markers found in {image_path}
#  26%|██▌       | 391/1500 [00:12<00:32, 34.03it/s]WARNING:root:Ignoring 24 sliver markers.
# WARNING:root:Ignoring 21 sliver markers.
# WARNING:root:Ignoring 20 sliver markers.
# WARNING:root:Ignoring 26 sliver markers.
#  26%|██▋       | 395/1500 [00:12<00:31, 34.56it/s]WARNING:root:Ignoring 24 sliver markers.
# WARNING:root:Ignoring 23 sliver markers.
# WARNING:root:Ignoring 24 sliver markers.
# WARNING:root:Ignoring 26 sliver markers.
#  27%|██▋       | 399/1500 [00:12<00:31, 35.39it/s]WARNING:root:Ignoring 24 sliver markers.
# WARNING:root:Ignoring 26 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 25 sliver markers.
#  27%|██▋       | 403/1500 [00:12<00:30, 36.08it/s]WARNING:root:Ignoring 24 sliver markers.
# WARNING:root:Ignoring 23 sliver markers.
# WARNING:root:Ignoring 23 sliver markers.
# WARNING:root:Ignoring 20 sliver markers.
#  27%|██▋       | 407/1500 [00:12<00:29, 36.74it/s]WARNING:root:Ignoring 25 sliver markers.
# WARNING:root:Ignoring 24 sliver markers.
# WARNING:root:Ignoring 24 sliver markers.
# WARNING:root:Ignoring 23 sliver markers.
#  27%|██▋       | 411/1500 [00:13<00:29, 36.61it/s]WARNING:root:Ignoring 24 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 19 sliver markers.
# WARNING:root:Ignoring 21 sliver markers.
#  28%|██▊       | 415/1500 [00:13<00:29, 37.37it/s]WARNING:root:Ignoring 23 sliver markers.
# WARNING:root:Ignoring 19 sliver markers.
# WARNING:root:Ignoring 16 sliver markers.
# WARNING:root:Ignoring 18 sliver markers.
#  28%|██▊       | 419/1500 [00:13<00:28, 37.98it/s]WARNING:root:Ignoring 14 sliver markers.
# WARNING:root:Ignoring 10 sliver markers.
# WARNING:root:Ignoring 7 sliver markers.
# WARNING:root:Ignoring 5 sliver markers.
#  28%|██▊       | 423/1500 [00:13<00:28, 37.61it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 6 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  29%|██▊       | 428/1500 [00:13<00:27, 38.88it/s]WARNING:root:Ignoring 1 sliver markers.
# WARNING:root:Ignoring 1 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  29%|██▉       | 433/1500 [00:13<00:26, 39.70it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  29%|██▉       | 438/1500 [00:13<00:26, 40.33it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  30%|██▉       | 443/1500 [00:13<00:25, 40.97it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 9 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  30%|██▉       | 448/1500 [00:13<00:25, 40.78it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 1 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  30%|███       | 453/1500 [00:14<00:25, 40.87it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  31%|███       | 458/1500 [00:14<00:26, 39.65it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 5 sliver markers.
#  31%|███       | 462/1500 [00:14<00:26, 38.77it/s]WARNING:root:Ignoring 3 sliver markers.
# WARNING:root:Ignoring 3 sliver markers.
# WARNING:root:Ignoring 4 sliver markers.
# WARNING:root:Ignoring 2 sliver markers.
#  31%|███       | 466/1500 [00:14<00:28, 36.26it/s]WARNING:root:Ignoring 4 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 4 sliver markers.
# WARNING:root:Ignoring 7 sliver markers.
#  31%|███▏      | 470/1500 [00:14<00:28, 36.02it/s]WARNING:root:Ignoring 7 sliver markers.
# WARNING:root:Ignoring 6 sliver markers.
# WARNING:root:Ignoring 7 sliver markers.
# WARNING:root:Ignoring 9 sliver markers.
#  32%|███▏      | 474/1500 [00:14<00:29, 35.13it/s]WARNING:root:Ignoring 4 sliver markers.
# WARNING:root:Ignoring 10 sliver markers.
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  32%|███▏      | 478/1500 [00:14<00:32, 31.48it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  32%|███▏      | 482/1500 [00:14<00:31, 32.30it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  32%|███▏      | 486/1500 [00:15<00:30, 32.96it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  33%|███▎      | 490/1500 [00:15<00:30, 33.27it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:Ignoring 1 sliver markers.
# WARNING:root:No markers found in {image_path}
#  33%|███▎      | 494/1500 [00:15<00:29, 33.63it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  33%|███▎      | 498/1500 [00:15<00:29, 34.04it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  40%|████      | 606/1500 [00:18<00:27, 31.93it/s]WARNING:root:Ignoring 1 sliver markers.
#  42%|████▏     | 625/1500 [00:19<00:30, 28.48it/s]WARNING:root:Ignoring 1 sliver markers.
#  46%|████▌     | 687/1500 [00:21<00:24, 33.34it/s]WARNING:root:1 duplicate IDs found, ignoring
#  51%|█████▏    | 769/1500 [00:23<00:22, 32.05it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  52%|█████▏    | 773/1500 [00:24<00:21, 33.83it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  52%|█████▏    | 777/1500 [00:24<00:20, 34.71it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  52%|█████▏    | 781/1500 [00:24<00:21, 33.34it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  62%|██████▏   | 932/1500 [00:28<00:19, 29.23it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  62%|██████▏   | 936/1500 [00:29<00:18, 30.18it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  63%|██████▎   | 940/1500 [00:29<00:18, 31.09it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  63%|██████▎   | 944/1500 [00:29<00:17, 31.28it/s]WARNING:root:No markers found in {image_path}
#  65%|██████▌   | 979/1500 [00:30<00:20, 25.50it/s]WARNING:root:Ignoring 1 sliver markers.
#  66%|██████▌   | 985/1500 [00:30<00:20, 25.55it/s]WARNING:root:Ignoring 1 sliver markers.
#  67%|██████▋   | 1000/1500 [00:31<00:18, 26.79it/s]WARNING:root:1 duplicate IDs found, ignoring
# WARNING:root:1 duplicate IDs found, ignoring
#  74%|███████▍  | 1112/1500 [00:35<00:12, 31.06it/s]WARNING:root:1 duplicate IDs found, ignoring
#  77%|███████▋  | 1160/1500 [00:36<00:10, 31.19it/s]WARNING:root:1 duplicate IDs found, ignoring
# WARNING:root:1 duplicate IDs found, ignoring
# WARNING:root:1 duplicate IDs found, ignoring
#  78%|███████▊  | 1164/1500 [00:36<00:10, 30.61it/s]WARNING:root:1 duplicate IDs found, ignoring
# WARNING:root:1 duplicate IDs found, ignoring
# WARNING:root:1 duplicate IDs found, ignoring
#  78%|███████▊  | 1168/1500 [00:36<00:11, 29.84it/s]WARNING:root:1 duplicate IDs found, ignoring
#  78%|███████▊  | 1171/1500 [00:37<00:11, 29.27it/s]WARNING:root:1 duplicate IDs found, ignoring
#  78%|███████▊  | 1174/1500 [00:37<00:11, 28.63it/s]WARNING:root:1 duplicate IDs found, ignoring
# WARNING:root:1 duplicate IDs found, ignoring
# WARNING:root:1 duplicate IDs found, ignoring
#  78%|███████▊  | 1177/1500 [00:37<00:12, 25.98it/s]WARNING:root:1 duplicate IDs found, ignoring
# WARNING:root:1 duplicate IDs found, ignoring
#  81%|████████▏ | 1220/1500 [00:38<00:09, 29.77it/s]WARNING:root:1 duplicate IDs found, ignoring
#  84%|████████▍ | 1266/1500 [00:40<00:07, 30.68it/s]WARNING:root:1 duplicate IDs found, ignoring
#  85%|████████▍ | 1270/1500 [00:40<00:07, 30.67it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  85%|████████▍ | 1274/1500 [00:40<00:07, 31.46it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  85%|████████▌ | 1278/1500 [00:40<00:06, 32.34it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  85%|████████▌ | 1282/1500 [00:40<00:06, 32.81it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  86%|████████▌ | 1286/1500 [00:40<00:06, 32.94it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  86%|████████▌ | 1290/1500 [00:41<00:06, 32.94it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  86%|████████▋ | 1294/1500 [00:41<00:06, 32.42it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  88%|████████▊ | 1322/1500 [00:41<00:05, 33.83it/s]WARNING:root:Ignoring 1 sliver markers.
#  89%|████████▉ | 1334/1500 [00:42<00:04, 33.57it/s]WARNING:root:1 duplicate IDs found, ignoring
#  93%|█████████▎| 1402/1500 [00:44<00:02, 33.00it/s]WARNING:root:1 duplicate IDs found, ignoring
#  95%|█████████▍| 1418/1500 [00:44<00:02, 31.33it/s]WARNING:root:1 duplicate IDs found, ignoring
# WARNING:root:1 duplicate IDs found, ignoring
# WARNING:root:1 duplicate IDs found, ignoring
#  95%|█████████▍| 1422/1500 [00:45<00:02, 30.47it/s]WARNING:root:1 duplicate IDs found, ignoring
#  95%|█████████▌| 1426/1500 [00:45<00:02, 29.95it/s]WARNING:root:1 duplicate IDs found, ignoring
#  96%|█████████▌| 1433/1500 [00:45<00:02, 28.20it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  96%|█████████▌| 1436/1500 [00:45<00:02, 27.34it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  96%|█████████▌| 1439/1500 [00:45<00:02, 27.32it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  96%|█████████▌| 1443/1500 [00:45<00:01, 28.65it/s]WARNING:root:No markers found in {image_path}
# WARNING:root:No markers found in {image_path}
#  97%|█████████▋| 1455/1500 [00:46<00:01, 26.84it/s]WARNING:root:1 duplicate IDs found, ignoring
# 100%|██████████| 1500/1500 [00:47<00:00, 31.42it/s]

# %%
exhaustive_match(image_ids, image_paths, db_path, args, image_id_desc, input_image_path)
# Out:
# INFO:root:Matching features
# 100%|██████████| 1500/1500 [33:38<00:00,  1.35s/it]
# INFO:root:Writing image pairs at tmp/brics_calib/match_list.txt

# %%
logging.info("Performing geometric verification")
subprocess.run([
    "colmap", "matches_importer",
    "--database_path", db_path,
    "--match_list_path", f"{os.path.join(tmp_dir, 'match_list.txt')}",
    "--match_type", "pairs",
    "--SiftMatching.min_num_inliers", "1",
    "--SiftMatching.use_gpu", "0"
])
# Out:
# INFO:root:Performing geometric verification
# ==============================================================================
# Custom feature matching
# ==============================================================================
#
# Matching block [1/5934]
# *** Aborted at 1675724944 (unix time) try "date -d @1675724944" if you are using GNU date ***
# PC: @     0x55a2855822f8 (unknown)
# *** SIGSEGV (@0x0) received by PID 39791 (TID 0x7f952aff5700) from PID 0; stack trace: ***
#     @     0x7f953ce75631 (unknown)
#     @     0x7f953c3b8420 (unknown)
#     @     0x55a2855822f8 (unknown)
#     @     0x55a285584470 colmap::TwoViewGeometry::EstimateUncalibrated()
#     @     0x55a28559d1df colmap::TwoViewGeometryVerifier::Run()
#     @     0x55a2856a5101 colmap::Thread::RunFunc()
#     @     0x7f953b6bade4 (unknown)
#     @     0x7f953c3ac609 start_thread
#     @     0x7f953b363133 clone
# CompletedProcess(args=['colmap', 'matches_importer', '--database_path', 'tmp/brics_calib/db.db', '--match_list_path', 'tmp/brics_calib/match_list.txt', '--match_type', 'pairs', '--SiftMatching.min_num_inliers', '1', '--SiftMatching.use_gpu', '0'], returncode=-11)

# %%
logging.info("Reconstructing")
recon_path = os.path.join(tmp_dir, "reconstruction")
create_dir(recon_path)
subprocess.run([
    "colmap", "mapper",
    "--database_path", db_path,
    "--image_path", image_path,
    "--output_path", recon_path,
])
# Out:
# INFO:root:Reconstructing
# WARNING:root:Deleting files at tmp/brics_calib/reconstruction
# ==============================================================================
# Loading database
# ==============================================================================
#
# Loading cameras... 3 in 0.000s
# Loading matches... 0 in 0.000s
# Loading images... 1500 in 0.002s (connected 0)
# Building correspondence graph... in 0.000s (ignored 0)
#
# Elapsed time: 0.000 [minutes]
#
# WARNING: No images with matches found in the database.
# CompletedProcess(args=['colmap', 'mapper', '--database_path', 'tmp/brics_calib/db.db', '--image_path', 'tmp/brics_calib/images', '--output_path', 'tmp/brics_calib/reconstruction'], returncode=0)

# %%
logging.info("Performing global bundle adjustment")
subprocess.run([
    "colmap", "bundle_adjuster",
    "--input_path", os.path.join(recon_path, "0"),
    "--output_path", os.path.join(recon_path, "0"),
    "--BundleAdjustment.refine_principal_poin", "1"
])
# Out:
# INFO:root:Performing global bundle adjustment
# ==============================================================================
# Global bundle adjustment
# ==============================================================================
#
# iter      cost      cost_change  |gradient|   |step|    tr_ratio  tr_radius  ls_iter  iter_time  total_time
#    0
#   96  5.550171e+02    7.90e-04    8.09e+01   1.31e+00   6.21e-01  1.15e+07        1    5.74e-02    4.76e+00
#   97  5.550163e+02    7.63e-04    7.99e+01   1.29e+00   6.22e-01  1.17e+07        1    6.37e-02    4.82e+00
#   98  5.550156e+02    7.36e-04    7.89e+01   1.28e+00   6.23e-01  1.19e+07        1    6.00e-03    4.83e+00
#   99  5.550149e+02    7.10e-04    7.79e+01   1.26e+00   6.24e-01  1.20e+07        1    6.67e-03    4.84e+00
#  100  5.550142e+02    6.85e-04    7.68e+01   1.25e+00   6.25e-01  1.22e+07        1    7.06e-02    4.91e+00
#
#
# Bundle adjustment report
# ------------------------
#     Residuals : 4500
#    Parameters : 531
#    Iterations : 101
#          Time : 4.90645 [s]
#  Initial cost : 0.351707 [px]
#    Final cost : 0.351193 [px]
#   Termination : No convergence
#
# Elapsed time: 0.082 [minutes]
# CompletedProcess(args=['colmap', 'bundle_adjuster', '--input_path', 'tmp/brics_calib/reconstruction/0', '--output_path', 'tmp/brics_calib/reconstruction/0', '--BundleAdjustment.refine_principal_poin', '1'], returncode=0)

# %%
output_dir = os.path.join(tmp_dir, "output")
create_dir(output_dir)
subprocess.run([
    "colmap", "model_converter",
    "--input_path", os.path.join(recon_path, "0"),
    "--output_path", output_dir,
    "--output_type", "TXT"
])
# Out:
# WARNING:root:Deleting files at tmp/brics_calib/output
# CompletedProcess(args=['colmap', 'model_converter', '--input_path', 'tmp/brics_calib/reconstruction/0', '--output_path', 'tmp/brics_calib/output', '--output_type', 'TXT'], returncode=0)

# %%
# Read images
image_params = []
with open(os.path.join(output_dir, "images.txt")) as f:
    skip_next = False
    for line in f.readlines():
        if skip_next:
            skip_next = False
            continue
        if line.startswith("#"):
            continue
        data = line.split()
        param = []
        param.append(int(data[8]))
        param.append(data[9].split("/")[0])
        param += [float(datum) for datum in data[1:8]]
        image_params.append(tuple(param))
        skip_next = True

images = np.array(image_params, dtype=[
    ('cam_id', int), ('cam_name', '<U22'),
    ('qvecw', float), ('qvecx', float), ('qvecy', float), ('qvecz', float),
    ('tvecx', float), ('tvecy', float), ('tvecz', float)
])

# Read cameras
cam_params = []
with open(os.path.join(output_dir, "cameras.txt")) as f:
    for line in f.readlines():
        if line.startswith("#"):
            continue
        data = line.split()
        param = []
        param.append(int(data[0]))
        param.append(int(data[2]))
        param.append(int(data[3]))
        param += [float(datum) for datum in data[4:]]
        cam_params.append(tuple(param))
cameras = np.array(cam_params, dtype=[
    ('cam_id', int),
    ('width', int), ('height', int),
    ('fx', float), ('fy', float),
    ('cx', float), ('cy', float),
    ('k1', float), ('k2', float),
    ('p1', float), ('p2', float),
])

img_cams = rf.join_by('cam_id', cameras, images)
if args.separate_calib:
    create_dir(os.path.join(args.root_dir, 'calib'))
np.savetxt(os.path.join(args.root_dir, 'calib', 'params.txt'), img_cams, fmt="%s", header=" ".join(img_cams.dtype.fields))

logging.warning(f"Stored the parameters at {os.path.join(args.root_dir, 'calib', 'params.txt')}")
# Out:
# WARNING:root:Stored the parameters at ./calib/params.txt
